# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('max_colwidth', None)

# %%
df =  pd.read_excel("pizza.xlsx")
df
# Out:
#        pizza_id  order_id  pizza_name_id  quantity order_date order_time  \
# 0             1         1     hawaiian_m         1 2015-01-01   11:38:36
# 1             2         2  classic_dlx_m         1 2015-01-01   11:57:40
# 2             3         2  five_cheese_l         1 2015-01-01   11:57:40
# 3             4         2    ital_supr_l         1 2015-01-01   11:57:40
# 4             5         2     mexicana_m         1 2015-01-01   11:57:40
# ...         ...       ...            ...       ...        ...        ...
# 48615     48616     21348  ckn_alfredo_m         1 2015-12-31   21:23:10
# 48616     48617     21348  four_cheese_l         1 2015-12-31   21:23:10
# 48617     48618     21348   napolitana_s         1 2015-12-31   21:23:10
# 48618     48619     21349     mexicana_l         1 2015-12-31   22:09:54
# 48619     48620     21350      bbq_ckn_s         1 2015-12-31   23:02:05
#
#        unit_price  total_price pizza_size pizza_category  \
# ...

# %%
df.columns
# Out:
# Index(['pizza_id', 'order_id', 'pizza_name_id', 'quantity', 'order_date',
#        'order_time', 'unit_price', 'total_price', 'pizza_size',
#        'pizza_category', 'pizza_ingredients', 'pizza_name'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   pizza_id           48620 non-null  int64
#  1   order_id           48620 non-null  int64
#  2   pizza_name_id      48620 non-null  object
#  3   quantity           48620 non-null  int64
#  4   order_date         48620 non-null  datetime64[ns]
#  5   order_time         48620 non-null  object
#  6   unit_price         48620 non-null  float64
#  7   total_price        48620 non-null  float64
#  8   pizza_size         48620 non-null  object
#  9   pizza_category     48620 non-null  object
#  10  pizza_ingredients  48620 non-null  object
#  11  pizza_name         48620 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(3), object(6)
# memory usage: 4.5+ MB

# %%
df['pizza_category'].unique()
# Out:
# array(['Classic', 'Veggie', 'Supreme', 'Chicken'], dtype=object)

# %% [markdown]
# ## Unique Values for different columns

# %%
print(df['pizza_category'].unique())
print(df['quantity'].unique())
print(df['pizza_size'].unique())
print(df['pizza_name'].unique() , "len : " , len(df['pizza_name'].unique()))
# Out:
# ['Classic' 'Veggie' 'Supreme' 'Chicken']
# [1 2 3 4]
# ['M' 'L' 'S' 'XL' 'XXL']
# ['The Hawaiian Pizza' 'The Classic Deluxe Pizza' 'The Five Cheese Pizza'
#  'The Italian Supreme Pizza' 'The Mexicana Pizza' 'The Thai Chicken Pizza'
#  'The Prosciutto and Arugula Pizza' 'The Barbecue Chicken Pizza'
#  'The Greek Pizza' 'The Spinach Supreme Pizza' 'The Green Garden Pizza'
#  'The Italian Capocollo Pizza' 'The Spicy Italian Pizza'
#  'The Spinach Pesto Pizza' 'The Vegetables + Vegetables Pizza'
#  'The Southwest Chicken Pizza' 'The California Chicken Pizza'
#  'The Pepperoni Pizza' 'The Chicken Pesto Pizza' 'The Big Meat Pizza'
#  'The Soppressata Pizza' 'The Four Cheese Pizza' 'The Napolitana Pizza'
#  'The Calabrese Pizza' 'The Italian Vegetables Pizza'
#  'The Mediterranean Pizza' 'The Pepper Salami Pizza'
#  'The Spinach and Feta Pizza' 'The Sicilian Pizza'
#  'The Chicken Alfredo Pizza' 'The Pepperoni, Mushroom, and Peppers Pizza'
#  'The Brie Carre Pizza'] len :  32

# %%
df.head()
# Out:
#    pizza_id  order_id  pizza_name_id  quantity order_date order_time  \
# 0         1         1     hawaiian_m         1 2015-01-01   11:38:36
# 1         2         2  classic_dlx_m         1 2015-01-01   11:57:40
# 2         3         2  five_cheese_l         1 2015-01-01   11:57:40
# 3         4         2    ital_supr_l         1 2015-01-01   11:57:40
# 4         5         2     mexicana_m         1 2015-01-01   11:57:40
#
#    unit_price  total_price pizza_size pizza_category  \
# 0       13.25        13.25          M        Classic
# 1       16.00        16.00          M        Classic
# 2       18.50        18.50          L         Veggie
# 3       20.75        20.75          L        Supreme
# 4       16.00        16.00          M         Veggie
#
#                                                                               pizza_ingredients  \
# 0                                                      Sliced Ham, Pineapple, Mozzarella Cheese
# ...

# %% [markdown]
# ## Most popular pizzas

# %% [markdown]
# ##### MOST SOLD

# %%
df.groupby('pizza_name').agg({'quantity' : ['sum']}).sort_values(by=('quantity', 'sum'), ascending=False)
# Out:
#                                            quantity
#                                                 sum
# pizza_name
# The Classic Deluxe Pizza                       2453
# The Barbecue Chicken Pizza                     2432
# The Hawaiian Pizza                             2422
# The Pepperoni Pizza                            2418
# The Thai Chicken Pizza                         2371
# The California Chicken Pizza                   2370
# The Sicilian Pizza                             1938
# The Spicy Italian Pizza                        1924
# The Southwest Chicken Pizza                    1917
# The Big Meat Pizza                             1914
# The Four Cheese Pizza                          1902
# The Italian Supreme Pizza                      1884
# The Vegetables + Vegetables Pizza              1526
# The Mexicana Pizza                             1484
# The Napolitana Pizza                           1464
# The Prosciutto and Arugula Pizza               1457
# ...

# %%
grouped_sold = df.groupby('pizza_name').agg({'quantity' : ['sum']})
top_5 = grouped_sold.sort_values(by=("quantity", "sum"), ascending=False).head(5)

top_5.plot(kind='bar', legend = None, color = 'r')
plt.title("Top 5 most sold pizzas")
plt.xlabel("Pizza Names")
plt.ylabel("Quantity")
plt.show()

# %% [markdown]
# ##### MOST PROFITABLE

# %%
df.groupby('pizza_name').agg({'total_price' : ['sum']}).sort_values(by=('total_price', 'sum'), ascending=False)
# Out:
#                                            total_price
#                                                    sum
# pizza_name
# The Thai Chicken Pizza                        43434.25
# The Barbecue Chicken Pizza                    42768.00
# The California Chicken Pizza                  41409.50
# The Classic Deluxe Pizza                      38180.50
# The Spicy Italian Pizza                       34831.25
# The Southwest Chicken Pizza                   34705.75
# The Italian Supreme Pizza                     33476.75
# The Hawaiian Pizza                            32273.25
# The Four Cheese Pizza                         32265.70
# The Sicilian Pizza                            30940.50
# The Pepperoni Pizza                           30161.75
# The Greek Pizza                               28454.10
# The Mexicana Pizza                            26780.75
# The Five Cheese Pizza                         26066.50
# The Pepper Salami Pizza                       25529.00
# ...

# %%
grouped_profit = df.groupby('pizza_name').agg({'total_price' : ['sum']})
top_5 = grouped_profit.sort_values(by = ("total_price", "sum"), ascending=False).head(5)

top_5.plot(kind='bar', legend = None)
plt.title("Top 5 most profitable pizzas")
plt.xlabel("Pizza Names")
plt.ylabel("Price")
plt.show()

# %%
df[df['pizza_name'] == 'The Thai Chicken Pizza'].head(1)['total_price']
# Out:
# 5    20.75
# Name: total_price, dtype: float64

# %% [markdown]
# ##### MOST EXPENSIVE PIZZA

# %%
df[df['total_price'] == df['total_price'].max()]['pizza_name'].unique()
# Out:
# array(['The California Chicken Pizza'], dtype=object)

# %% [markdown]
# ##### CHEAPEST PIZZA

# %%
df[df['total_price'] == df['total_price'].min()]['pizza_name'].unique()
# Out:
# array(['The Pepperoni Pizza'], dtype=object)

# %%
df.head()
# Out:
#    pizza_id  order_id  pizza_name_id  quantity order_date order_time  \
# 0         1         1     hawaiian_m         1 2015-01-01   11:38:36
# 1         2         2  classic_dlx_m         1 2015-01-01   11:57:40
# 2         3         2  five_cheese_l         1 2015-01-01   11:57:40
# 3         4         2    ital_supr_l         1 2015-01-01   11:57:40
# 4         5         2     mexicana_m         1 2015-01-01   11:57:40
#
#    unit_price  total_price pizza_size pizza_category  \
# 0       13.25        13.25          M        Classic
# 1       16.00        16.00          M        Classic
# 2       18.50        18.50          L         Veggie
# 3       20.75        20.75          L        Supreme
# 4       16.00        16.00          M         Veggie
#
#                                                                               pizza_ingredients  \
# 0                                                      Sliced Ham, Pineapple, Mozzarella Cheese
# ...

# %% [markdown]
# #####  MOST SOLD PIZZA SIZE

# %%
df.groupby('pizza_size').agg({'quantity' : ['sum']}).sort_values(by=('quantity', 'sum'), ascending=False)
# Out:
#            quantity
#                 sum
# pizza_size
# L             18956
# M             15635
# S             14403
# XL              552
# XXL              28

# %% [markdown]
# ##### MOST SOLD PIZZA CATEGORY

# %%
df.groupby('pizza_category').agg({'quantity' : ['sum']}).sort_values(by=('quantity', 'sum'), ascending=False)
# Out:
#                quantity
#                     sum
# pizza_category
# Classic           14888
# Supreme           11987
# Veggie            11649
# Chicken           11050

# %% [markdown]
# ##### CATEGORY WISE ANALYTICS

# %%
(df.groupby(['pizza_size', 'pizza_category'])
                 .agg({'quantity' : ['sum']}))
# Out:
#                           quantity
#                                sum
# pizza_size pizza_category
# L          Chicken            4932
#            Classic            4057
#            Supreme            4564
#            Veggie             5403
# M          Chicken            3894
#            Classic            4112
#            Supreme            4046
#            Veggie             3583
# S          Chicken            2224
#            Classic            6139
#            Supreme            3377
#            Veggie             2663
# XL         Classic             552
# XXL        Classic              28

# %%
(df.groupby(['pizza_size', 'pizza_category'])
                 .agg({'quantity' : ['sum']})).sort_values(by=('quantity', 'sum'), ascending=False)
# Out:
#                           quantity
#                                sum
# pizza_size pizza_category
# S          Classic            6139
# L          Veggie             5403
#            Chicken            4932
#            Supreme            4564
# M          Classic            4112
# L          Classic            4057
# M          Supreme            4046
#            Chicken            3894
#            Veggie             3583
# S          Supreme            3377
#            Veggie             2663
#            Chicken            2224
# XL         Classic             552
# XXL        Classic              28

# %%
df[df['quantity'] > 1]
# Out:
#        pizza_id  order_id   pizza_name_id  quantity order_date order_time  \
# 48           49        17  mediterraneo_m         2 2015-01-01   13:53:00
# 183         184        78    spicy_ital_l         3 2015-01-02   12:28:14
# 211         212        91       bbq_ckn_l         2 2015-01-02   15:14:43
# 222         223        92     the_greek_m         2 2015-01-02   15:17:02
# 245         246       105      hawaiian_s         2 2015-01-02   18:12:01
# ...         ...       ...             ...       ...        ...        ...
# 48461     48462     21285    spin_pesto_s         2 2015-12-31   12:41:37
# 48466     48467     21288   classic_dlx_m         3 2015-12-31   13:04:18
# 48495     48496     21298      big_meat_s         2 2015-12-31   15:35:37
# 48575     48576     21331       bbq_ckn_l         2 2015-12-31   19:05:04
# 48601     48602     21343    spicy_ital_l         2 2015-12-31   20:27:23
#
#        unit_price  total_price pizza_size pizza_category  \
# ...

# %% [markdown]
# ### SALES OVER TIME

# %%
# TOTAL PERIOD
print(df['order_date'].min())
print(df['order_date'].max())
# Out:
# 2015-01-01 00:00:00
# 2015-12-31 00:00:00

# %% [markdown]
# ##### DAILY SALES

# %%
df.groupby('order_date').agg({'total_price' : 'sum'})
# Out:
#             total_price
# order_date
# 2015-01-01      2713.85
# 2015-01-02      2731.90
# 2015-01-03      2662.40
# 2015-01-04      1755.45
# 2015-01-05      2065.95
# ...                 ...
# 2015-12-27      1419.00
# 2015-12-28      1637.20
# 2015-12-29      1353.25
# 2015-12-30      1337.80
# 2015-12-31      2916.00
#
# [358 rows x 1 columns]

# %%
date_index = df.copy()
date_index['order_date'] = pd.to_datetime(df['order_date'])

#set index as date
date_index.set_index(date_index['order_date'], inplace = True)

monthly_sales = date_index.resample('M').agg({'total_price': 'sum'})
monthly_sales
# Out:
#             total_price
# order_date
# 2015-01-31     69793.30
# 2015-02-28     65159.60
# 2015-03-31     70397.10
# 2015-04-30     68736.80
# 2015-05-31     71402.75
# 2015-06-30     68230.20
# 2015-07-31     72557.90
# 2015-08-31     68278.25
# 2015-09-30     64180.05
# 2015-10-31     64027.60
# 2015-11-30     70395.35
# 2015-12-31     64701.15

# %% [markdown]
# ##### MONTH WITH MAX SALES

# %%
monthly_sales.index[monthly_sales['total_price'] == monthly_sales['total_price'].max()]
# Out:
# DatetimeIndex(['2015-07-31'], dtype='datetime64[ns]', name='order_date', freq='M')

# %% [markdown]
# ##### MONTH WITH MIN SALES

# %%
monthly_sales.index[monthly_sales['total_price'] == monthly_sales['total_price'].min()]
# Out:
# DatetimeIndex(['2015-10-31'], dtype='datetime64[ns]', name='order_date', freq='M')

# %% [markdown]
# ##### MEAN SALES

# %%
monthly_sales['total_price'].mean()
# Out:
# 68155.00416666667

# %% [markdown]
# ##### MONTH V REVENUE

# %%
monthly_sales.plot(legend=None)
plt.xlabel("Month")
plt.ylabel("Revenue")
# Out:
# Text(0, 0.5, 'Revenue')

# %%
# TOTAL SALES IN 2015
monthly_sales['total_price'].sum()
# Out:
# 817860.05

# %%
df.head()
# Out:
#    pizza_id  order_id  pizza_name_id  quantity order_date order_time  \
# 0         1         1     hawaiian_m         1 2015-01-01   11:38:36
# 1         2         2  classic_dlx_m         1 2015-01-01   11:57:40
# 2         3         2  five_cheese_l         1 2015-01-01   11:57:40
# 3         4         2    ital_supr_l         1 2015-01-01   11:57:40
# 4         5         2     mexicana_m         1 2015-01-01   11:57:40
#
#    unit_price  total_price pizza_size pizza_category  \
# 0       13.25        13.25          M        Classic
# 1       16.00        16.00          M        Classic
# 2       18.50        18.50          L         Veggie
# 3       20.75        20.75          L        Supreme
# 4       16.00        16.00          M         Veggie
#
#                                                                               pizza_ingredients  \
# 0                                                      Sliced Ham, Pineapple, Mozzarella Cheese
# ...

# %% [markdown]
# #### Finding The Peak Hours

# %%
time_index = df.copy()
time_index['order_time'] = time_index['order_time'].apply(lambda x: x.strftime('%H:%M:%S'))
time_index['order_time'] = pd.to_datetime(time_index['order_time'])
time_index.set_index('order_time', inplace=True)
time_index

hourly_sales = time_index.resample('H').agg({'quantity' : ['sum']})
hourly_sales.sort_values(by=('quantity', 'sum'), ascending=False)
# Out:
#                     quantity
#                          sum
# order_time
# 2024-05-25 12:00:00     6776
# 2024-05-25 13:00:00     6413
# 2024-05-25 18:00:00     5417
# 2024-05-25 17:00:00     5211
# 2024-05-25 19:00:00     4406
# 2024-05-25 16:00:00     4239
# 2024-05-25 14:00:00     3613
# 2024-05-25 20:00:00     3534
# 2024-05-25 15:00:00     3216
# 2024-05-25 11:00:00     2728
# 2024-05-25 21:00:00     2545
# 2024-05-25 22:00:00     1386
# 2024-05-25 23:00:00       68
# 2024-05-25 10:00:00       18
# 2024-05-25 09:00:00        4

# %% [markdown]
# ### Recommender

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
def recommend(pizza_name, df = df):
    df_rec = df.copy()
    
    text_data = df_rec['pizza_category'] + df_rec['pizza_ingredients'] + df_rec['pizza_name']
    rel_features = ['pizza_name', 'pizza_ingredients', 'pizza_category']
    
    tfidf = TfidfVectorizer()
    tfidf_matrix = tfidf.fit_transform(text_data)
    
    query_vec = tfidf.transform([pizza_name])
    query_sim = cosine_similarity(query_vec, tfidf_matrix)[0]
    query_rec = query_sim.argsort()[::-1][:1]
    
    return df_rec[rel_features].iloc[query_rec]

# %%
recommend("Veggie spinach")
# Out:
#                       pizza_name  \
# 4399  The Spinach and Feta Pizza
#
#                                         pizza_ingredients pizza_category
# 4399  Spinach, Mushrooms, Red Onions, Feta Cheese, Garlic         Veggie
